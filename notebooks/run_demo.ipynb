# %% [markdown]
# # ARSPM Framework Demo
# Run training + one evaluation episode, then generate plots in `outputs/`.

# %%
# !python ../run_experiment.py
# Out:
# device: cpu
# Traceback (most recent call last):
#   File "/Users/Morty/Desktop/毕业设计/Code/RUL_GRU/arspm_framework/notebooks/../run_experiment.py", line 176, in <module>
#     main()
#   File "/Users/Morty/Desktop/毕业设计/Code/RUL_GRU/arspm_framework/notebooks/../run_experiment.py", line 55, in main
#     df0 = pd.read_csv(cfg.TRAIN_CSV)
#   File "/opt/anaconda3/envs/GPU/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 948, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/opt/anaconda3/envs/GPU/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 611, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/opt/anaconda3/envs/GPU/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1448, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "/opt/anaconda3/envs/GPU/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1705, in _make_engine
#     self.handles = get_handle(
# ...
